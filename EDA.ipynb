# %%
# import libery
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go 
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# read dataset
df = pd.read_csv ('Hotel Reservations.csv')

# %%
# dataset top 5 records
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
# dataset last 5 records
df.tail()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36270                  6       Meal Plan 1                           0
# 36271                  3       Meal Plan 1                           0
# 36272                  6       Meal Plan 1                           0
# 36273                  3      Not Selected                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# ...

# %%
# get the basic info about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
# descriptive summary of dataset
df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %%
# dataset size ( row and columns)
df.size
# Out:
# 689225

# %%
# dataset sample
df.sample()
# Out:
#      Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 2170   INN02171             2               0                     1
#
#       no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 2170                  3       Meal Plan 1                           0
#
#      room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 2170        Room_Type 1         83          2018              5             2
#
#      market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 2170             Offline               0                             0
#
#       no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 2170                                     0               80.75
#
#       no_of_special_requests booking_status
# 2170                       0   Not_Canceled

# %%
# dataset shape ( row and columns)
df.shape
# Out:
# (36275, 19)

# %%
# dataset all columns
df.columns.tolist()
# Out:
# ['Booking_ID',
#  'no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'type_of_meal_plan',
#  'required_car_parking_space',
#  'room_type_reserved',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'market_segment_type',
#  'repeated_guest',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'booking_status']

# %%
# Define Unique Values per Column
print("Unique Values per Column:")
for col in df.columns:
 print(f"➙ {col}: {df[col].nunique()} unique values")
# Out:
# Unique Values per Column:
# ➙ Booking_ID: 36275 unique values
# ➙ no_of_adults: 5 unique values
# ➙ no_of_children: 6 unique values
# ➙ no_of_weekend_nights: 8 unique values
# ➙ no_of_week_nights: 18 unique values
# ➙ type_of_meal_plan: 4 unique values
# ➙ required_car_parking_space: 2 unique values
# ➙ room_type_reserved: 7 unique values
# ➙ lead_time: 352 unique values
# ➙ arrival_year: 2 unique values
# ➙ arrival_month: 12 unique values
# ➙ arrival_date: 31 unique values
# ➙ market_segment_type: 5 unique values
# ➙ repeated_guest: 2 unique values
# ➙ no_of_previous_cancellations: 9 unique values
# ➙ no_of_previous_bookings_not_canceled: 59 unique values
# ➙ avg_price_per_room: 3930 unique values
# ➙ no_of_special_requests: 6 unique values
# ➙ booking_status: 2 unique values

# %%
# all columns datatype
df.dtypes
# Out:
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
# create all columns data type Tabel
data_type = pd.DataFrame({
    'All Columns Name': df.columns,
    'All Columns Datatype': [str(df[i].dtypes) for i in df.columns]
})
# showing dataframe by table 
table = go.Figure(data=[go.Table(
    header=dict(values=["All Columns Name", "All Columns Datatype"],
                fill_color='grey',
                align='left'),
    cells=dict(values=[data_type['All Columns Name'], data_type['All Columns Datatype']],
               fill_color='lavender',
               align='left'))
])

table.update_layout(title="All Columns Data Type Table")
table.show()

# %%
# cheak missing values
df.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %% [markdown]
# # Observation
# dataset haven't any missing values

# %%
#check dataset duplicated value
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Observation
# dataset haven't any duplicated values

# %% [markdown]
# # Data Analysis - EDA

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 14 numerical features : ['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'required_car_parking_space', 'lead_time', 'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room', 'no_of_special_requests']
#
# We have 5 categorical features : ['Booking_ID', 'type_of_meal_plan', 'room_type_reserved', 'market_segment_type', 'booking_status']

# %% [markdown]
# # Observation
# data have 14 numerical columns and 5 categorical columns

# %% [markdown]
# # Feature Information
#
# 1. Booking_ID: unique identifier of each booking
# 2. no_of_adults: Number of adults
# 3. no_of_children: Number of Children
# 4. no_of_weekend_nights: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# 5. no_of_week_nights: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# 6. type_of_meal_plan: Type of meal plan booked by the customer:
# 7. required_car_parking_space: Does the customer require a car parking space? (0 - No, 1- Yes)
# 8. room_type_reserved: Type of room reserved by the customer. The values are ciphered (encoded) by INN Hotels.
# 9. lead_time: Number of days between the date of booking and the arrival date
# 10. arrival_year: Year of arrival date
# 11. arrival_month: Month of arrival date
# 12. arrival_date: Date of the month
# 13. market_segment_type: Market segment designation.
# 14. repeated_guest: Is the customer a repeated guest? (0 - No, 1- Yes)
# 15. no_of_previous_cancellations: Number of previous bookings that were canceled by the customer prior to the current booking
# 16. no_of_previous_bookings_not_canceled: Number of previous bookings not canceled by the customer prior to the current booking
# 17. avg_price_per_room: Average price per day of the reservation; prices of the rooms are dynamic. (in euros)
# 18. no_of_special_requests: Total number of special requests made by the customer (e.g. high floor, view from the room, etc)
# 19. booking_status: Flag indicating if the booking was canceled or not.

# %%
# Univarite Analysis of Numerical Feature
plt.figure (figsize = (15,15))
plt.suptitle ('Univarite Analysis of Numerical Feature' , fontsize = 20 , fontweight = 'bold',alpha = 0.8,y = 1 )

for i in range (0 , len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x = df[numeric_features[i]] , shade = True , color="#f7ab79")
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# # Task-1.  Distribution plot → How many adults come to most bookings.

# %%
fig = px.histogram(df,x="no_of_adults",nbins=10,title="Distribution of Number of Adults per Booking",text_auto=True,color_discrete_sequence=["#1f77b4"])
fig.update_layout(xaxis_title="Number of Adults", yaxis_title="Number of Bookings", bargap=0.1)
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> The histogram shows that the most bookings have 2 adults.
# </P>

# %% [markdown]
# # Task-2.  Boxplot with avg_price_per_room → What is the price of a room if there are more adults?

# %%
fig = px.box(df,  x="no_of_adults", y="avg_price_per_room", color="no_of_adults",title="Room Price Distribution by Number of Adults",labels={"no_of_adults": "Number of Adults", "avg_price_per_room": "Average Price per Room"})
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> As can be seen from the boxplot, the more adults there are, the more avg_price_per_room increases.  When the number of adults increases to 2, the room prices rise, with the highest concentration of bookings around 540
# </P>

# %% [markdown]
# # Task-3.  Countplot → What % of bookings have kids?

# %%
# Countplot using Plotly
fig = px.bar(df['no_of_children'].value_counts().sort_index(),
             x=df['no_of_children'].value_counts().sort_index().index,
             y=df['no_of_children'].value_counts().sort_index().values,
             labels={'x':'Number of Children', 'y':'Number of Bookings'},
             title='Number of Children per Booking')

fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> This plot shows that most of the time there are no children when booking a room, and very few people come with 1 or 2 kids.
# </P>

# %% [markdown]
# # Task-4. Cancellation relation → Are bookings with children more likely to be cancelled?

# %%
df['children_status'] = df['no_of_children'].apply(lambda x: 'Has_Children' if x>0 else 'No_Children')
cancel_data = df.groupby(['children_status', 'booking_status']).size().reset_index(name='count')
fig = px.bar(cancel_data,x='children_status',y='count',color='booking_status',barmode='group',title='Booking Cancellation by Children Presence',
labels={'children_status':'Children in Booking', 'count':'Number of Bookings', 'booking_status':'Booking Status'})
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> This chart shows that if bookings with kids are not as cancelled, then bookings without kids are not cancelled as much.
# </P>

# %% [markdown]
# # Task-5. Distribution → How many nights do customers stay on weekends?

# %%
fig = px.histogram(df,x='no_of_weekend_nights', nbins=10,title='Distribution of Weekend Nights Stayed by Customers',labels={'no_of_weekend_nights':'Number of Weekend Nights'})
fig.update_layout(bargap=0.2)
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> Most of the time customers don't stay on weekend nights, but some customers stay for 1 or 2 days on weekend nights.
# </P>

# %% [markdown]
# # Task-6.Compare with booking_status → whether long weekend booking cancellations are more frequent.

# %%
fig = px.histogram( df,x="no_of_weekend_nights",color="booking_status",barmode="group",title="Weekend Nights vs Booking Status",labels={
        "no_of_weekend_nights": "Number of Weekend Nights",
        "booking_status": "Booking Status"})

fig.update_layout(xaxis_title="Weekend Nights",yaxis_title="Number of Bookings",bargap=0.2)
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> Those who don't stay on weekend nights don't get canceled much.
# </P>

# %% [markdown]
# # Task- 7. Histogram → How long in advance is booking made?

# %%
fig = px.histogram(df,x='lead_time',nbins=50,title='Lead Time Distribution (Days before arrival)',
labels={'lead_time':'Days before arrival'},color_discrete_sequence=["#3db41f"])
fig.update_layout(bargap=0.1)
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> Most of the people 0-9 dayes before booking made.
# </P>

# %% [markdown]
# # Task- 8. Pie chart → What % of guests repeat.

# %%
fig = px.pie(df,names='repeated_guest',title='Repeated vs New Guests',hole=0.2,color='repeated_guest',color_discrete_map={0: 'pink', 1: 'black'}  )
fig.update_traces(textinfo='percent+label')  
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> This plot showing repeated guests percent label 1.256% and new guest percent label 97.4%
# </P>

# %% [markdown]
# # Task- 9. Line plot → In which month are bookings higher (seasonality).

# %%
month_map = {
    1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',
    7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
df['arrival_month_name'] = df['arrival_month'].map(month_map)
monthly_bookings = df.groupby('arrival_month_name').size().reset_index(name='bookings')
month_order = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
monthly_bookings['arrival_month_name'] = pd.Categorical(monthly_bookings['arrival_month_name'],categories=month_order, ordered=True)
monthly_bookings = monthly_bookings.sort_values('arrival_month_name')
fig = px.line(monthly_bookings,x='arrival_month_name',y='bookings',title='Monthly Booking Trend')
fig.update_layout(xaxis_title='Month', yaxis_title='Number of Bookings')
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> Octobar Month have the most booking and january Month have lowest booking
# </P>

# %% [markdown]
# # Task- 10. Cancellation pattern → Which month has the most cancellations?

# %%
cancelled = df[df['booking_status'] == 'Canceled']
cancel_by_month = cancelled.groupby('arrival_month').size().reset_index(name='cancellations')
fig = px.bar(cancel_by_month,x='arrival_month',y='cancellations',text='cancellations',title='Monthly Booking Cancellations',labels={'arrival_month':'Month','cancellations':'Number of Cancellations'},color='cancellations',color_continuous_scale='reds')
fig.update_traces(texttemplate='%{text}', textposition='outside')
fig.update_layout(yaxis_title='Cancellations', xaxis_title='Month', xaxis=dict(dtick=1), height = 600 )
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> Octobar month have the most booking cancellation
# </P>

# %% [markdown]
# # Task- 11. Histogram → Which price range has the most bookings?

# %%
fig = px.histogram(df,x='avg_price_per_room',nbins=50,title='Distribution of Average Price per Room',labels={'avg_price_per_room': 'Average Price per Room'})
fig.update_layout(
    bargap=0.05,
    xaxis_title='Average Price per Room',
    yaxis_title='Number of Bookings')
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P> whcih room has Average price 90-109.99 , that room booking most

# %% [markdown]
# # Task- 12.  Popular room type

# %%
room_counts = df['room_type_reserved'].value_counts().reset_index()
room_counts.columns = ['room_type_reserved', 'count']
fig = px.bar( room_counts, x='room_type_reserved', y='count', color='room_type_reserved', title='Most Popular Room Types', text='count')
fig.update_traces(textposition='outside')
fig.update_layout(xaxis_title='Room Type', yaxis_title='Number of Bookings', height = 600)
fig.show()

# %% [markdown]
# <h4>Observation of this analysis </h4>
# <P>Popular Room type is Room_Type 1</P>

# %% [markdown]
# _________________
